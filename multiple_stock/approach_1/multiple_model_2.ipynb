# %%
# !pip install yfinance==0.2.44 numpy pandas scikit-learn tensorflow pandas_ta
# Out:
# Collecting yfinance==0.2.44
#   Downloading yfinance-0.2.44-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.10/site-packages (2.16.1)
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.10/site-packages (from yfinance==0.2.44) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance==0.2.44)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in /opt/conda/lib/python3.10/site-packages (from yfinance==0.2.44) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from yfinance==0.2.44) (3.11.0)
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.10/site-packages (from yfinance==0.2.44) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.10/site-packages (from yfinance==0.2.44) (2.4.4)
# Collecting peewee>=3.16.2 (from yfinance==0.2.44)
#   Downloading peewee-3.17.7.tar.gz (939 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.5/939.5 kB 24.5 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.10/site-packages (from yfinance==0.2.44) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /opt/conda/lib/python3.10/site-packages (from yfinance==0.2.44) (1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.44) (2.5)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from html5lib>=1.1->yfinance==0.2.44) (0.5.1)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance==0.2.44) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance==0.2.44) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance==0.2.44) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31->yfinance==0.2.44) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)
# Downloading yfinance-0.2.44-py2.py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 5.3 MB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: pandas_ta, peewee
#   Building wheel for pandas_ta (setup.py) ... done
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218910 sha256=a6c0a247bd6733245d50455dfd6095aa3540131b479ee19224ec817e4391662f
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.17.7-cp310-cp310-linux_x86_64.whl size=300449 sha256=e807af8fa2a46f462573c77fdc450f5e77bcd940ac30463b738211c2d2d89d45
#   Stored in directory: /root/.cache/pip/wheels/8d/0e/f8/48eb93a200fca4c502d7590613616fa4d2c9533f7308f9e28a
# Successfully built pandas_ta peewee
# Installing collected packages: peewee, multitasking, yfinance, pandas_ta
# Successfully installed multitasking-0.0.11 pandas_ta-0.3.14b0 peewee-3.17.7 yfinance-0.2.44

# %%
import yfinance as yf
import pandas as pd

# Download historical data for multiple stocks
stock_symbols = [
    'AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'META', 'NVDA', 'JPM', 'JNJ', 'V',
    'PG', 'UNH', 'DIS', 'MA', 'HD', 'PYPL', 'BAC', 'XOM', 'KO', 'PFE',
    'PEP', 'NFLX', 'CSCO', 'ABT', 'MRK', 'INTC', 'VZ', 'CVX', 'MCD', 'WMT',
    'BMY', 'IBM', 'C', 'NKE', 'T', 'ORCL', 'CRM', 'HON', 'BA',
    'AMGN', 'UPS', 'COST', 'LLY', 'WFC', 'MDT', 'DHR', 'TXN', 'LMT', 'GS'
]

# Download historical adjusted closing prices
data = yf.download(stock_symbols, start="2004-01-01", end="2024-01-01")['Adj Close']

# Calculate correlation matrix
correlation_matrix = data.corr()

# Sort the correlation matrix by the 'AAPL' column
sorted_correlation = correlation_matrix['AAPL'].sort_values(ascending=False)

# Print the sorted correlation values
print(sorted_correlation)
# Out:
# [*********************100%***********************]  49 of 49 completed
# Ticker
# AAPL     1.000000
# MSFT     0.990276
# COST     0.986885
# UNH      0.973383
# DHR      0.972768
# GOOGL    0.971393
# PG       0.962954
# TXN      0.959816
# UPS      0.957076
# WMT      0.957019
# HD       0.956130
# ORCL     0.955141
# ABT      0.952237
# PEP      0.949062
# MA       0.948286
# TSLA     0.946402
# MCD      0.946379
# LLY      0.930886
# V        0.929292
# JPM      0.926749
# NVDA     0.926083
# MRK      0.920231
# NKE      0.920166
# AMZN     0.916962
# HON      0.913989
# GS       0.910504
# CRM      0.909070
# JNJ      0.906887
# KO       0.905439
# AMGN     0.904372
# LMT      0.903087
# CSCO     0.893242
# PFE      0.870923
# NFLX     0.849612
# CVX      0.844068
# MDT      0.806477
# BMY      0.802590
# META     0.799381
# DIS      0.720340
# INTC     0.719229
# VZ       0.710586
# XOM      0.676308
# T        0.660919
# IBM      0.612435
# WFC      0.579133
# BA       0.556136
# BAC      0.454856
# PYPL     0.452934
# C       -0.353525
# Name: AAPL, dtype: float64

# %%
import yfinance as yf
import pandas as pd

def calculate_sma(data, window):
    return data.rolling(window=window).mean()

def calculate_ema(data, window):
    return data.ewm(span=window, adjust=False).mean()

def calculate_rsi(data, window=14):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

def download_and_merge_stocks_with_tech(stock_symbols, start_date='2000-01-01', end_date='2024-10-10'):
    stock_dataframes = []

    for idx, stock in enumerate(stock_symbols):
        data = yf.download(stock, start=start_date, end=end_date)
        print(f"Downloaded data for {stock}:")
#         print(data.head())  # Debug: Check the first few rows of each stock's data

        stock_label = f'Stock{idx + 1}'
        data = data[['Open', 'Close', 'Volume', 'Adj Close']].rename(columns={
            'Open': f'Open_{stock_label}',
            'Close': f'Close_{stock_label}',
            'Volume': f'Volume_{stock_label}',
            'Adj Close': f'Adj_Close_{stock_label}'
        })

        # Calculate technical indicators manually
#         data[f'{stock_label}_SMA_20'] = calculate_sma(data[f'Close_{stock_label}'], window=20)
#         data[f'{stock_label}_EMA_20'] = calculate_ema(data[f'Close_{stock_label}'], window=10)
#         data[f'{stock_label}_RSI'] = calculate_rsi(data[f'Close_{stock_label}'], window=14)

        stock_dataframes.append(data)

    # Merging all stock data into a single dataframe
    merged_data = stock_dataframes[0]
    for df in stock_dataframes[1:]:
        merged_data = pd.merge(merged_data, df, left_index=True, right_index=True)

    # Check the merged data shape before dropping NaN
    print(f"Shape after merging stock data: {merged_data.shape}")

    # Handle missing data: Try not dropping rows aggressively
    merged_data.fillna(method='ffill', inplace=True)  # Forward fill missing values

    # Check final data
    print(f"Final data shape after handling missing values: {merged_data.shape}")

    return merged_data

# Example stock symbols
# stock_symbols = ['ADANIPORTS.NS', 'BPCL.NS', 'ONGC.NS']
stock_symbols = ['ADANIPORTS.NS', 'ONGC.NS', 'BPCL.NS']
# stock_symbols=['JPM','C','BAC']
# Download the stock data and add technical indicators
data_with_tech = download_and_merge_stocks_with_tech(stock_symbols)

# View the first few rows of the dataset
print(data_with_tech.head())
data=data_with_tech
data.shape
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloaded data for ADANIPORTS.NS:
# Downloaded data for ONGC.NS:
# [*********************100%***********************]  1 of 1 completed
# Downloaded data for BPCL.NS:
# Shape after merging stock data: (4156, 12)
# Final data shape after handling missing values: (4156, 12)
#             Open_Stock1  Close_Stock1  Volume_Stock1  Adj_Close_Stock1  \
# Date
# 2007-11-27   154.000000    191.800003       27262365        174.525635
# 2007-11-28   194.000000    177.000000       21958915        161.058578
# 2007-11-29   181.000000    177.399994       25616715        161.422546
# 2007-11-30   178.000000    185.800003       23047035        169.065994
# 2007-12-03   187.949997    196.000000       14578850        178.347366
#
#             Open_Stock2  Close_Stock2  Volume_Stock2  Adj_Close_Stock2  \
# Date
# 2007-11-27   196.658340    195.449997        8661552         96.386909
# 2007-11-28   196.725006    191.708328        4797564         94.541702
# 2007-11-29   193.391663    189.550003       11414208         93.477325
# 2007-11-30   190.741669    194.591660        6807900         95.963593
# 2007-12-03   193.333328    195.050003        7218324         96.189659
#
#             Open_Stock3  Close_Stock3  Volume_Stock3  Adj_Close_Stock3
# Date
# 2007-11-27    32.666664     33.908333        3292560         16.554287
# 2007-11-28    34.166664     32.041664       17387052         15.642968
# 2007-11-29    33.750000     31.858334       10442520         15.553465
# 2007-11-30    32.504166     32.195831        7968696         15.718233
# 2007-12-03    32.825001     33.570831        5419512         16.389521
# /tmp/ipykernel_30/3819227679.py:49: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   merged_data.fillna(method='ffill', inplace=True)  # Forward fill missing values
# (4156, 12)

# %%
# Scale the features using MinMaxScaler
import numpy as np
import pandas as pd
import yfinance as yf
import pandas_ta as ta
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Input, Concatenate, Bidirectional, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from tensorflow.keras.callbacks import EarlyStopping

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# Create a DataFrame from the scaled data
scaled_data = pd.DataFrame(scaled_data, columns=data.columns, index=data.index)

print("Scaled data shape:", scaled_data.shape)
# Out:
# Scaled data shape: (4156, 12)

# %%
scaled_data.isna().sum()
scaled_data.dropna(inplace=True)

print("Scaled data shape:", scaled_data.shape)
# Out:
# Scaled data shape: (4156, 12)

# %%
# Function to create datasets
def create_dataset(data, time_step, num_stocks):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:(i + time_step), :])
        y.append(data[i + time_step - 1, 6:6 + num_stocks])  # Close prices for each stock
    return np.array(X), np.array(y)

# Create the dataset
time_step = 60
num_stocks = len(stock_symbols)
X, y = create_dataset(scaled_data.values, time_step, num_stocks)

# %%
# Split data into training, validation, and testing sets
train_size = int(len(X) * 0.7)
val_size = int(len(X) * 0.15)
test_size = len(X) - train_size - val_size

X_train, X_val, X_test = X[:train_size], X[train_size:train_size + val_size], X[train_size + val_size:]
y_train, y_val, y_test = y[:train_size], y[train_size:train_size + val_size], y[train_size + val_size:]

# %%
import tensorflow as tf
def quantile_loss(q):
    def loss(y_true, y_pred):
        err = y_true - y_pred
        return tf.reduce_mean(tf.where(err >= 0, q * err, (q - 1) * err))
    return loss

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,GRU, MultiHeadAttention, LSTM,Attention ,Dense, Dropout, Conv1D, MaxPooling1D,Bidirectional,TimeDistributed,Concatenate
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
n=int(len(stock_symbols)/2)
# Input layer
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
# x_encoded = TimeDistributed(Dense(n, activation='linear'))(input_layer)  # Further reduce to 8 dimensions
# x_encoded = TimeDistributed(Dense(4, activation='relu'))(x_encoded)
# Convolutional and LSTM layers
x = (Conv1D(filters=64, kernel_size=7, activation='relu'))(input_layer)
x = MaxPooling1D(pool_size=4)(x)
# x_encoded= Bidirectional(LSTM(64, return_sequences=True))(input_layer)
x1 = Bidirectional(LSTM(64, return_sequences=True))(input_layer)
x1 = Dropout(0.1)(x1)
# x1 = Attention()([x1, x1])
# x1 = MultiHeadAttention(num_heads=3, key_dim=16)(x1, x1,x1)
# x=Concatenate([x,x1])

# x2 = Bidirectional(LSTM(64,return_sequences=True))(input_layer)
x2 = Bidirectional(GRU(64, return_sequences=True))(input_layer)
x2 = Dropout(0.1)(x2)
x = Concatenate()([x1, x2])
x = Bidirectional(LSTM(32, return_sequences=False))(x)
x= Dropout(0.2)(x)
# x = LSTM(64, return_sequences=False)(x)
# x = Dropout(0.2)(x)
x = Dense(24, activation='relu')(x)

outputs = [Dense(1, name=f'stock_{i+1}_output')(x) for i in range(num_stocks)]

# Define the model with multiple outputs
model = Model(inputs=input_layer, outputs=outputs)
# Define the loss for each output using quantile_loss(0.5) for each stock
losses = {f'stock_{i+1}_output': Huber() for i in range(num_stocks)}

# Define the metrics for each stock's output (e.g., 'mse' for each stock)
metrics = {f'stock_{i+1}_output': ['mse'] for i in range(num_stocks)}

# Define the loss weights for each stock to give equal importance
loss_weights = {f'stock_{i+1}_output': 1/num_stocks for i in range(num_stocks)}

# Compile the model with the adjusted losses, metrics, and loss weights
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=losses,                   # Custom losses for each output
    metrics=metrics,                # Custom metrics for each output
    loss_weights=loss_weights       # Equal weight for each output
)
model.summary()
# Out:
# Model: "functional_41"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_24      │ (None, 60, 12)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_56    │ (None, 60, 128)   │     39,424 │ input_layer_24[0… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_57    │ (None, 60, 128)   │     29,952 │ input_layer_24[0… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_56          │ (None, 60, 128)   │          0 │ bidirectional_56… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_57          │ (None, 60, 128)   │          0 │ bidirectional_57… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 60, 256)   │          0 │ dropout_56[0][0], │
# │ (Concatenate)       │                   │            │ dropout_57[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_58    │ (None, 64)        │     73,984 │ concatenate_7[0]… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_58          │ (None, 64)        │          0 │ bidirectional_58… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 24)        │      1,560 │ dropout_58[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stock_1_output      │ (None, 1)         │         25 │ dense_20[0][0]    │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stock_2_output      │ (None, 1)         │         25 │ dense_20[0][0]    │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stock_3_output      │ (None, 1)         │         25 │ dense_20[0][0]    │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 144,995 (566.39 KB)
#  Trainable params: 144,995 (566.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
# Separate target values for each stock
y_train_stocks = [y_train[:, i] for i in range(num_stocks)]
y_val_stocks = [y_val[:, i] for i in range(num_stocks)]
y_test_stocks = [y_test[:, i] for i in range(num_stocks)]

# Fit the model
history = model.fit(
    X_train,
    y_train_stocks,
    epochs=50,
    batch_size=16,
    validation_data=(X_val, y_val_stocks),
    shuffle=True,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 0.0028 - stock_1_output_mse: 0.0020 - stock_2_output_mse: 0.0065 - stock_3_output_mse: 0.0086 - val_loss: 0.0040 - val_stock_1_output_mse: 0.0150 - val_stock_2_output_mse: 0.0064 - val_stock_3_output_mse: 0.0028
# Epoch 2/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 5.7172e-04 - stock_1_output_mse: 0.0011 - stock_2_output_mse: 0.0010 - stock_3_output_mse: 0.0014 - val_loss: 0.0036 - val_stock_1_output_mse: 0.0156 - val_stock_2_output_mse: 0.0035 - val_stock_3_output_mse: 0.0024
# Epoch 3/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 5.1198e-04 - stock_1_output_mse: 0.0012 - stock_2_output_mse: 8.2537e-04 - stock_3_output_mse: 0.0011 - val_loss: 0.0034 - val_stock_1_output_mse: 0.0157 - val_stock_2_output_mse: 0.0031 - val_stock_3_output_mse: 0.0014
# Epoch 4/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 3.9424e-04 - stock_1_output_mse: 7.6893e-04 - stock_2_output_mse: 6.5284e-04 - stock_3_output_mse: 9.4368e-04 - val_loss: 0.0024 - val_stock_1_output_mse: 0.0111 - val_stock_2_output_mse: 0.0016 - val_stock_3_output_mse: 0.0018
# Epoch 5/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 4.2420e-04 - stock_1_output_mse: 0.0013 - stock_2_output_mse: 4.9912e-04 - stock_3_output_mse: 7.8252e-04 - val_loss: 0.0022 - val_stock_1_output_mse: 0.0106 - val_stock_2_output_mse: 0.0013 - val_stock_3_output_mse: 0.0014
# Epoch 6/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 3.2216e-04 - stock_1_output_mse: 8.2104e-04 - stock_2_output_mse: 4.2016e-04 - stock_3_output_mse: 6.9178e-04 - val_loss: 0.0020 - val_stock_1_output_mse: 0.0091 - val_stock_2_output_mse: 0.0013 - val_stock_3_output_mse: 0.0014
# Epoch 7/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 2.7744e-04 - stock_1_output_mse: 6.3256e-04 - stock_2_output_mse: 4.0423e-04 - stock_3_output_mse: 6.2788e-04 - val_loss: 0.0015 - val_stock_1_output_mse: 0.0071 - val_stock_2_output_mse: 6.4234e-04 - val_stock_3_output_mse: 0.0012
# Epoch 8/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 2.7346e-04 - stock_1_output_mse: 7.1593e-04 - stock_2_output_mse: 3.6895e-04 - stock_3_output_mse: 5.5591e-04 - val_loss: 0.0014 - val_stock_1_output_mse: 0.0059 - val_stock_2_output_mse: 8.8671e-04 - val_stock_3_output_mse: 0.0015
# Epoch 9/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 2.2248e-04 - stock_1_output_mse: 5.7625e-04 - stock_2_output_mse: 2.9983e-04 - stock_3_output_mse: 4.5881e-04 - val_loss: 0.0011 - val_stock_1_output_mse: 0.0039 - val_stock_2_output_mse: 5.5571e-04 - val_stock_3_output_mse: 0.0021
# Epoch 10/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 2.1920e-04 - stock_1_output_mse: 5.5598e-04 - stock_2_output_mse: 2.7712e-04 - stock_3_output_mse: 4.8206e-04 - val_loss: 0.0012 - val_stock_1_output_mse: 0.0046 - val_stock_2_output_mse: 5.3892e-04 - val_stock_3_output_mse: 0.0023
# Epoch 11/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 1.9578e-04 - stock_1_output_mse: 4.7207e-04 - stock_2_output_mse: 2.6513e-04 - stock_3_output_mse: 4.3745e-04 - val_loss: 0.0011 - val_stock_1_output_mse: 0.0032 - val_stock_2_output_mse: 8.5117e-04 - val_stock_3_output_mse: 0.0024
# Epoch 12/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 1.4908e-04 - stock_1_output_mse: 2.5223e-04 - stock_2_output_mse: 2.0659e-04 - stock_3_output_mse: 4.3567e-04 - val_loss: 7.6412e-04 - val_stock_1_output_mse: 0.0022 - val_stock_2_output_mse: 9.2290e-04 - val_stock_3_output_mse: 0.0015
# Epoch 13/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 1.5824e-04 - stock_1_output_mse: 3.0863e-04 - stock_2_output_mse: 2.0756e-04 - stock_3_output_mse: 4.3326e-04 - val_loss: 5.6383e-04 - val_stock_1_output_mse: 0.0011 - val_stock_2_output_mse: 9.2216e-04 - val_stock_3_output_mse: 0.0013
# Epoch 14/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 1.4747e-04 - stock_1_output_mse: 2.9149e-04 - stock_2_output_mse: 2.1507e-04 - stock_3_output_mse: 3.7823e-04 - val_loss: 4.4702e-04 - val_stock_1_output_mse: 9.3813e-04 - val_stock_2_output_mse: 3.1095e-04 - val_stock_3_output_mse: 0.0014
# Epoch 15/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 1.2916e-04 - stock_1_output_mse: 2.0295e-04 - stock_2_output_mse: 1.9183e-04 - stock_3_output_mse: 3.8019e-04 - val_loss: 3.8431e-04 - val_stock_1_output_mse: 5.9078e-04 - val_stock_2_output_mse: 2.8795e-04 - val_stock_3_output_mse: 0.0014
# Epoch 16/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 1.2025e-04 - stock_1_output_mse: 1.9281e-04 - stock_2_output_mse: 1.8946e-04 - stock_3_output_mse: 3.3925e-04 - val_loss: 6.7745e-04 - val_stock_1_output_mse: 0.0014 - val_stock_2_output_mse: 4.6062e-04 - val_stock_3_output_mse: 0.0022
# Epoch 17/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 1.0738e-04 - stock_1_output_mse: 1.5961e-04 - stock_2_output_mse: 1.7967e-04 - stock_3_output_mse: 3.0499e-04 - val_loss: 9.8345e-04 - val_stock_1_output_mse: 2.7778e-04 - val_stock_2_output_mse: 0.0023 - val_stock_3_output_mse: 0.0034
# Epoch 18/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 1.0618e-04 - stock_1_output_mse: 1.5048e-04 - stock_2_output_mse: 1.7214e-04 - stock_3_output_mse: 3.1443e-04 - val_loss: 4.8832e-04 - val_stock_1_output_mse: 0.0010 - val_stock_2_output_mse: 6.4344e-04 - val_stock_3_output_mse: 0.0013
# Epoch 19/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.0998e-04 - stock_1_output_mse: 1.2638e-04 - stock_2_output_mse: 1.7379e-04 - stock_3_output_mse: 3.5970e-04 - val_loss: 7.7016e-04 - val_stock_1_output_mse: 0.0011 - val_stock_2_output_mse: 4.0637e-04 - val_stock_3_output_mse: 0.0032
# Epoch 20/50
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 9.6793e-05 - stock_1_output_mse: 1.2325e-04 - stock_2_output_mse: 1.6490e-04 - stock_3_output_mse: 2.9261e-04 - val_loss: 4.8758e-04 - val_stock_1_output_mse: 4.9779e-04 - val_stock_2_output_mse: 6.9565e-04 - val_stock_3_output_mse: 0.0017

# %%
import pandas as pd

# Function to evaluate metrics and store results in a DataFrame
def evaluate_metrics_table(y_test, y_pred, stock_name, metrics_df):
    r2 = r2_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    
    # Create a temporary DataFrame to hold the new row of results
    temp_df = pd.DataFrame({
        'Stock': [stock_name],
        'R-squared': [r2],
        'MSE': [mse],
        'MAE': [mae]
    })
    
    # Concatenate the new row with the existing metrics_df
    metrics_df = pd.concat([metrics_df, temp_df], ignore_index=True)
    
    return metrics_df

# Initialize an empty DataFrame to store metrics for each stock
metrics_df = pd.DataFrame(columns=['Stock', 'R-squared', 'MSE', 'MAE'])

# Make predictions for the test set
y_pred_stocks = model.predict(X_test)

# Evaluate metrics for each stock and store them in the DataFrame
for i in range(num_stocks):
    metrics_df = evaluate_metrics_table(y_test_stocks[i], y_pred_stocks[i], f'Stock_{i+1}', metrics_df)

# Display the metrics as a table
print(metrics_df)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
#      Stock  R-squared       MSE       MAE
# 0  Stock_1   0.919737  0.000512  0.018575
# 1  Stock_2   0.774595  0.011548  0.080846
# 2  Stock_3   0.904998  0.003387  0.041474
# /tmp/ipykernel_30/2357702201.py:18: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   metrics_df = pd.concat([metrics_df, temp_df], ignore_index=True)

# %%
import matplotlib.pyplot as plt

# Extract keys related to validation loss from the history
val_loss_keys = [key for key in history.history.keys() if 'val_' in key and 'loss' in key]

# Initialize the plot
plt.figure(figsize=(10, 6))

# Plot overall validation loss first if present
if 'val_loss' in history.history:
    plt.plot(history.history['val_loss'], label='Overall Val Loss')

# Loop through each validation loss key and plot the loss for each stock output
for key in val_loss_keys:
    if key != 'val_loss':  # Exclude the overall validation loss, if plotted already
        stock_label = key.split('_output_')[0].replace('val_', '').title()  # Dynamically create stock labels
        plt.plot(history.history[key], label=f'{stock_label} Val Loss')

# Customize the plot
plt.title('Model Validation Loss for Each Output Head')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Make predictions
predictions = model.predict(X_test)

# Initialize the figure for plotting
plt.figure(figsize=(15, 5 * num_stocks))  # Adjust the height dynamically based on the number of stocks

# Loop through each stock and plot
for i in range(num_stocks):
    plt.subplot(num_stocks, 1, i + 1)  # Create subplot for each stock dynamically
    plt.plot(y_test_stocks[i], label=f'Actual Stock {i+1}', color='blue')
    plt.plot(predictions[i], label=f'Predicted Stock {i+1}', color='orange')
    plt.title(f'Stock {i+1}: Actual vs Predicted')
    plt.xlabel('Time Step')
    plt.ylabel('Stock Price')
    plt.legend()

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
model.save("model.h5")
